# %% [markdown]
# #  Partie 1: Récupération des données

# %% [markdown]
# Ce notebook à pour but de récupérer les données issues de la base de donnée du gouvernement de recencement des transactions immobilières, dans le cadre du projet "infrastructure de recharge"
#
# Les données ont été préalablement téléchargées au format csv depuis le site officiel du gouvernement et nommés selon la règle suivante:
#
# YYYY_XX.csv où YYYY corresponds à l'année en 4 chiffres et XX corresponds au numéro de département.

# %%
#Importation des fichiers csv:
import pandas as pd

idf2019_75=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_75.csv")
idf2019_77=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_77.csv")
idf2019_78=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_78.csv")
idf2019_91=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_91.csv")
idf2019_92=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_92.csv")
idf2019_93=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_93.csv")
idf2019_94=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_94.csv")
idf2019_95=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_95.csv")
# Out:
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\2121278549.py:4: DtypeWarning: Columns (18,20,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf2019_75=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_75.csv")
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\2121278549.py:5: DtypeWarning: Columns (14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf2019_77=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_77.csv")
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\2121278549.py:6: DtypeWarning: Columns (14,16,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf2019_78=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2019_78.csv")
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\2121278549.py:7: DtypeWarning: Columns (14,16) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
idf2020_75=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_75.csv")
idf2020_77=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_77.csv")
idf2020_78=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_78.csv")
idf2020_91=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_91.csv")
idf2020_92=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_92.csv")
idf2020_93=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_93.csv")
idf2020_94=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_94.csv")
idf2020_95=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_95.csv")
# Out:
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\3066558662.py:1: DtypeWarning: Columns (18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf2020_75=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_75.csv")
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\3066558662.py:2: DtypeWarning: Columns (18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf2020_77=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_77.csv")
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\3066558662.py:4: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf2020_91=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_91.csv")
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\3066558662.py:6: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf2020_93=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2020_93.csv")

# %%
idf2021_75=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_75.csv")
idf2021_77=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_77.csv")
idf2021_78=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_78.csv")
idf2021_91=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_91.csv")
idf2021_92=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_92.csv")
idf2021_93=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_93.csv")
idf2021_94=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_94.csv")
idf2021_95=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_95.csv")
# Out:
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\195595831.py:1: DtypeWarning: Columns (18,20,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf2021_75=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_75.csv")
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\195595831.py:2: DtypeWarning: Columns (17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf2021_77=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_77.csv")
# C:\Users\alaro\AppData\Local\Temp\ipykernel_24304\195595831.py:4: DtypeWarning: Columns (18,20,22,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   idf2021_91=pd.read_csv(r"C:\Users\alaro\Downloads\Dataset\2021_91.csv")

# %%
#Concaténation des dataframes créés en un seul dataframe:
df= pd.concat([idf2019_75, idf2019_77, idf2019_78, idf2019_91, idf2019_92, idf2019_93, idf2019_94, idf2019_95, 
              idf2020_75, idf2020_77, idf2020_78, idf2020_91, idf2020_92, idf2020_93, idf2020_94, idf2020_95, 
              idf2021_75, idf2021_77, idf2021_78, idf2021_91, idf2021_92, idf2021_93, idf2021_94, idf2021_95], axis=0)

df
# Out:
#         id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2019-1499564    2019-01-04                   1           Vente
# 1      2019-1499565    2019-01-03                   1           Vente
# 2      2019-1499565    2019-01-03                   1           Vente
# 3      2019-1499566    2019-01-08                   1           Vente
# 4      2019-1499567    2019-01-03                   1           Vente
# ...             ...           ...                 ...             ...
# 22143   2021-484774    2021-03-03                   1           Vente
# 22144   2021-484775    2021-03-10                   1           Vente
# 22145   2021-484775    2021-03-10                   1           Vente
# 22146   2021-484776    2021-02-23                   1           Vente
# 22147   2021-484776    2021-02-23                   1           Vente
#
#        valeur_fonciere  adresse_numero adresse_suffixe     adresse_nom_voie  \
# ...

# %%
#Export du dataframe vers un format csv:
df.to_csv("IDF_2019_to_2021.csv", index=False)
